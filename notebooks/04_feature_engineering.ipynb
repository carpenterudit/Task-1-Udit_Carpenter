# %% [markdown]
# # 04 feature engineering
# This notebook imports and reuses src modules; implementation remains in the backend.

# %%
import sys
sys.path.insert(0,'..')
from src.pipeline.preprocessing_pipeline import PreprocessingPipeline
